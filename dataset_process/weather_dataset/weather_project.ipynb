# %%
import pandas as pd

df=pd.read_csv("beach-weather-stations-automated-sensors-1.csv")

# %%
df
# Out:
#                       Station Name   Measurement Timestamp  Air Temperature  \
# 0       Oak Street Weather Station  05/22/2015 03:00:00 PM              NaN
# 1       Oak Street Weather Station  05/22/2015 05:00:00 PM              NaN
# 2       Oak Street Weather Station  05/22/2015 06:00:00 PM              NaN
# 3       Oak Street Weather Station  05/22/2015 07:00:00 PM              NaN
# 4       Oak Street Weather Station  05/22/2015 08:00:00 PM              NaN
# ...                            ...                     ...              ...
# 59139   Oak Street Weather Station  11/08/2017 12:00:00 AM             4.70
# 59140       Foster Weather Station  11/08/2017 12:00:00 AM             2.89
# 59141  63rd Street Weather Station  11/08/2017 01:00:00 AM             3.40
# 59142   Oak Street Weather Station  11/08/2017 01:00:00 AM             4.20
# 59143       Foster Weather Station  11/08/2017 01:00:00 AM             2.28
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59144 entries, 0 to 59143
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Station Name                 59144 non-null  object
#  1   Measurement Timestamp        59141 non-null  object
#  2   Air Temperature              59066 non-null  float64
#  3   Wet Bulb Temperature         38843 non-null  float64
#  4   Humidity                     59141 non-null  float64
#  5   Rain Intensity               38843 non-null  float64
#  6   Interval Rain                59141 non-null  float64
#  7   Total Rain                   38843 non-null  float64
#  8   Precipitation Type           38843 non-null  float64
#  9   Wind Direction               59141 non-null  float64
#  10  Wind Speed                   59141 non-null  float64
#  11  Maximum Wind Speed           59141 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Station Name                       0
# Measurement Timestamp              3
# Air Temperature                   78
# Wet Bulb Temperature           20301
# Humidity                           3
# Rain Intensity                 20301
# Interval Rain                      3
# Total Rain                     20301
# Precipitation Type             20301
# Wind Direction                     3
# Wind Speed                         3
# Maximum Wind Speed                 3
# Barometric Pressure              149
# Solar Radiation                    3
# Heading                        20301
# Battery Life                       3
# Measurement Timestamp Label        3
# Measurement ID                     0
# dtype: int64

# %%
df['Air Temperature'].fillna(df['Air Temperature'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Station Name                       0
# Measurement Timestamp              3
# Air Temperature                    0
# Wet Bulb Temperature           20301
# Humidity                           3
# Rain Intensity                 20301
# Interval Rain                      3
# Total Rain                     20301
# Precipitation Type             20301
# Wind Direction                     3
# Wind Speed                         3
# Maximum Wind Speed                 3
# Barometric Pressure              149
# Solar Radiation                    3
# Heading                        20301
# Battery Life                       3
# Measurement Timestamp Label        3
# Measurement ID                     0
# dtype: int64

# %%
df.drop(columns=['Wet Bulb Temperature'], inplace=True)

df.dropna(subset=['Measurement Timestamp'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Station Name                       0
# Measurement Timestamp              0
# Air Temperature                    0
# Humidity                           0
# Rain Intensity                 20298
# Interval Rain                      0
# Total Rain                     20298
# Precipitation Type             20298
# Wind Direction                     0
# Wind Speed                         0
# Maximum Wind Speed                 0
# Barometric Pressure              146
# Solar Radiation                    0
# Heading                        20298
# Battery Life                       0
# Measurement Timestamp Label        0
# Measurement ID                     0
# dtype: int64

# %%
df.drop(columns=['Heading'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Station Name                       0
# Measurement Timestamp              0
# Air Temperature                    0
# Humidity                           0
# Rain Intensity                 20298
# Interval Rain                      0
# Total Rain                     20298
# Precipitation Type             20298
# Wind Direction                     0
# Wind Speed                         0
# Maximum Wind Speed                 0
# Barometric Pressure              146
# Solar Radiation                    0
# Battery Life                       0
# Measurement Timestamp Label        0
# Measurement ID                     0
# dtype: int64

# %%
mean_barometric_pressure = df['Barometric Pressure'].mean()

# Replace NaN values in the 'Barometric Pressure' column with the calculated mean
df['Barometric Pressure'].fillna(mean_barometric_pressure, inplace=True)

# %%
df.isnull().sum()
# Out:
# Station Name                       0
# Measurement Timestamp              0
# Air Temperature                    0
# Humidity                           0
# Rain Intensity                 20298
# Interval Rain                      0
# Total Rain                     20298
# Precipitation Type             20298
# Wind Direction                     0
# Wind Speed                         0
# Maximum Wind Speed                 0
# Barometric Pressure                0
# Solar Radiation                    0
# Battery Life                       0
# Measurement Timestamp Label        0
# Measurement ID                     0
# dtype: int64

# %%
df['Rain Intensity'].fillna(df['Rain Intensity'].median(), inplace=True)
df['Total Rain'].fillna(df['Total Rain'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Station Name                       0
# Measurement Timestamp              0
# Air Temperature                    0
# Humidity                           0
# Rain Intensity                     0
# Interval Rain                      0
# Total Rain                         0
# Precipitation Type             20298
# Wind Direction                     0
# Wind Speed                         0
# Maximum Wind Speed                 0
# Barometric Pressure                0
# Solar Radiation                    0
# Battery Life                       0
# Measurement Timestamp Label        0
# Measurement ID                     0
# dtype: int64

# %%
df.drop(columns=['Precipitation Type'], inplace=True)

# %%
df
# Out:
#                       Station Name   Measurement Timestamp  Air Temperature  \
# 0       Oak Street Weather Station  05/22/2015 03:00:00 PM        13.282062
# 1       Oak Street Weather Station  05/22/2015 05:00:00 PM        13.282062
# 2       Oak Street Weather Station  05/22/2015 06:00:00 PM        13.282062
# 3       Oak Street Weather Station  05/22/2015 07:00:00 PM        13.282062
# 4       Oak Street Weather Station  05/22/2015 08:00:00 PM        13.282062
# ...                            ...                     ...              ...
# 59139   Oak Street Weather Station  11/08/2017 12:00:00 AM         4.700000
# 59140       Foster Weather Station  11/08/2017 12:00:00 AM         2.890000
# 59141  63rd Street Weather Station  11/08/2017 01:00:00 AM         3.400000
# 59142   Oak Street Weather Station  11/08/2017 01:00:00 AM         4.200000
# 59143       Foster Weather Station  11/08/2017 01:00:00 AM         2.280000
#
# ...

# %%
df.to_csv("beach_weather_station_no_missing_values.csv")

# %%
df=pd.read_csv("beach_weather_station_no_missing_values.csv")

# %%
df
# Out:
#        Unnamed: 0                 Station Name   Measurement Timestamp  \
# 0               0   Oak Street Weather Station  05/22/2015 03:00:00 PM
# 1               1   Oak Street Weather Station  05/22/2015 05:00:00 PM
# 2               2   Oak Street Weather Station  05/22/2015 06:00:00 PM
# 3               3   Oak Street Weather Station  05/22/2015 07:00:00 PM
# 4               4   Oak Street Weather Station  05/22/2015 08:00:00 PM
# ...           ...                          ...                     ...
# 59136       59139   Oak Street Weather Station  11/08/2017 12:00:00 AM
# 59137       59140       Foster Weather Station  11/08/2017 12:00:00 AM
# 59138       59141  63rd Street Weather Station  11/08/2017 01:00:00 AM
# 59139       59142   Oak Street Weather Station  11/08/2017 01:00:00 AM
# 59140       59143       Foster Weather Station  11/08/2017 01:00:00 AM
#
#        Air Temperature  Humidity  Rain Intensity  Interval Rain  Total Rain  \
# ...

# %%
import matplotlib.pyplot as plt
